# %% [markdown]
# # Capstone Two: Exploratory Data Analysis (EDA) - Hospital readmission for patients with diabetes

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
from matplotlib import pyplot as plt
import random
import numpy as np
# %matplotlib inline
from scipy.stats import norm
from scipy.stats import t
from IPython.core.interactiveshell import InteractiveShell

# %% [markdown]
# **Load the `df_clean.csv` file created during the Data Wrangling step into a dataframe and view the first 5 rows**

# %%
#load the dataframe
diabetes = pd.read_csv('data/df_clean.csv')
diabetes.head()
# Out:
#               race  gender      age admission_type_id  \
# 0        Caucasian  Female   [0-10)          Elective
# 1        Caucasian  Female  [10-20)         Emergency
# 2  AfricanAmerican  Female  [20-30)         Emergency
# 3        Caucasian    Male  [30-40)         Emergency
# 4        Caucasian    Male  [40-50)         Emergency
#
#   discharge_disposition_id admission_source_id  time_in_hospital  \
# 0               Not Mapped  Physician Referral                 1
# 1       Discharged to home      Emergency Room                 3
# 2       Discharged to home      Emergency Room                 2
# 3       Discharged to home      Emergency Room                 2
# 4       Discharged to home      Emergency Room                 1
#
#           medical_specialty  num_lab_procedures  num_procedures  ...  \
# 0  Pediatrics-Endocrinology                  41               0  ...
# 1           Surgery-General                  59               0  ...
# ...

# %%
#check the dataset's dimensions. 
diabetes.shape
# Out:
# (100042, 44)

# %%
#quick overview of the data (columns, variable type and non-null values)
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100042 entries, 0 to 100041
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      100042 non-null  object
#  1   gender                    100042 non-null  object
#  2   age                       100042 non-null  object
#  3   admission_type_id         100042 non-null  object
#  4   discharge_disposition_id  100042 non-null  object
#  5   admission_source_id       100042 non-null  object
#  6   time_in_hospital          100042 non-null  int64
#  7   medical_specialty         100042 non-null  object
#  8   num_lab_procedures        100042 non-null  int64
#  9   num_procedures            100042 non-null  int64
#  10  num_medications           100042 non-null  int64
#  11  num_outpatient_visit      100042 non-null  int64
#  12  num_emerg_visit           100042 non-null  int64
# ...

# %% [markdown]
# **Distributions of feature values: Plot histograms for each numeric variable in the dataframe to review the range and density**

# %%
#Plot histograms for 'num_emerg_visit'
diabetes['num_emerg_visit'].hist(figsize=(8,5), range=[0, 7])
plt.xlabel('Number of Emergency Visits')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Under 10,000 patients had only 1 emergency visit. Very few of the patients had between 2-6 emergency visits but the majority of patients had no emergency visits.

# %%
#Plot histograms for 'num_inpatient_visit'
diabetes['num_inpatient_visit'].hist(bins=10, figsize=(8,5), range=[0, 10])
plt.xlabel('Number of Inpatient Visits')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed right. The majority of patients did not have inpatient visits. Just under 20,000 patients had around 1 inpatient visit, under 10,000 patients had between 1-2 inpatient visits and very few patients had between 4-10 inpatient visits.

# %%
#Plot histograms for 'num_lab_procedures'
diabetes['num_lab_procedures'].hist(bins=40, figsize=(8,5))
plt.xlabel('Number of Lab Procedures')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The number of lab procedures spanned from about 0-110. Some patients had a higher number of lab procedures than everyone else, between 85-110. The majority of the patients had a range of about 25-70 lab procedures.

# %%
#Plot histograms for 'num_medications'
diabetes['num_medications'].hist(bins=35, figsize=(8,5))
plt.xlabel('Number of Distinct Generic Medications')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed right. Most of the patients had between 5-25 distincts medications administered, while a fewer number of patients had the highest number of medications administered, between 45 and just under 70 medications.

# %%
#Plot histograms for 'num_outpatient_visit'
diabetes['num_outpatient_visit'].hist(figsize=(8,5), range=[0, 8])
plt.xlabel('Number of Outpatient Visits')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed right. About 10,000 patients had 1-3 outpatient visit. Very few of the patients had between 4-8 outpatient visits but the majority of patients had no outpatient visits.

# %%
#Plot histograms for 'num_procedures'
diabetes['num_procedures'].hist(bins=10, figsize=(8,5))
plt.xlabel('Number of Non-Lab Procedures')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed right. On the right side there are a roughly 7,500 patients who had more Non-lab procedures, between 5-6, than the rest of the patients. About 25,000 patients had between 2-4, but most of the patients had between 0-1 Non-lab procedures.

# %%
#Plot histograms for 'number_diagnoses'
diabetes['number_diagnoses'].hist(bins=10, figsize=(8,5), range=[0,10])
plt.xlabel('Number of Diagnoses')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed left. On the left side there are a couple of hundred patients who had less number of diagnoses than the rest. Roughly half of the patients had between 4-8 diagnoses and the other half had around 9 diagnoses.

# %%
#Plot histograms for 'time_in_hospital'
diabetes['time_in_hospital'].hist(bins=10, figsize=(8,5))
plt.xlabel('Time Spent in Hospital (# days)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# This graph is skewed right. The patients spent a total of 1-14 days in the hospital before discharge. The majority of the patients spent between 1-6 days while the remainder spent a longer time in the hospital, 7-14 days, before discharge.

# %% [markdown]
# **Plot Boxplots for each numeric variable in the dataframe to look for outliers and anamolies**

# %%
#create a boxplot for 'num_emerg_visit'
diabetes.boxplot(column=['num_emerg_visit'], fontsize=15)

# %%
#create a boxplot for 'num_inpatient_visit'
diabetes.boxplot(column=['num_inpatient_visit'], fontsize=15)

# %%
#create a boxplot for 'num_lab_procedures'
diabetes.boxplot(column=['num_lab_procedures'], fontsize=15)

# %%
#create a boxplot for 'num_medications'
diabetes.boxplot(column=['num_medications'], fontsize=15)

# %%
#create a boxplot for 'num_outpatient_visit'
diabetes.boxplot(column=['num_outpatient_visit'], fontsize=15)

# %%
#create a boxplot for 'num_procedures'
diabetes.boxplot(column=['num_procedures'], fontsize=15)

# %%
#create a boxplot for 'number_diagnoses'
diabetes.boxplot(column=['number_diagnoses'], fontsize=15)

# %%
#create a boxplot for 'time_in_hospital'
diabetes.boxplot(column=['time_in_hospital'], fontsize=15)

# %% [markdown]
# ## Visualize Relationships between Variables

# %% [markdown]
# **Plot the pairwise relationships in the dataset to see how the variables relate to one another**

# %%
#create scatterplots between all of the variables
sns.pairplot(diabetes)

# %% [markdown]
# There doesn't seem to be too much correlation between the variables.

# %% [markdown]
# **Correlation Heatmap Matrix**

# %%
#create a correlation heatmap for looking at the correlation of all variables/features
plt.subplots(figsize=(17,14))
sns.heatmap(diabetes.corr(), linewidths=0.1, annot=True)

# %% [markdown]
# There seems to be a slight correlation between the `num_of_medications` and `time_in_hospital`, but not too much correlation between any of the other variables, which agres with the scatterplots.

# %% [markdown]
# **Let's look as some demographics: Race, Age and Gender**

# %%
#plot the 'race' variable
plt.figure(figsize = (8,5))
ax = sns.countplot(x='race', data=diabetes)
plt.xlabel('Race')
# Out:
# Text(0.5, 0, 'Race')

# %% [markdown]
# Majority of the population in the data set belongs to the Caucasian Race followed by African American.

# %%
#plot the 'age' variable
plt.figure(figsize = (10,5))
ax = sns.countplot(x='age', data=diabetes)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# The age ranges from 10-100 but the majority of the patients are in the 50-90 age range.

# %%
#plot the 'gender' variable
ax = sns.countplot(x='gender', data=diabetes)
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %% [markdown]
# There are more Females than Males but the data is almost equally distributed among the two categories.

# %% [markdown]
# **Let's plot some graghs comparing Race, Age and Gender**

# %%
#plot the 'race' and 'gender' variables
sns.set()
plt.figure(figsize = (8,5))
ax = sns.countplot(x='race', hue='gender', data=diabetes)
plt.xlabel('Patient\'s Race')
plt.ylabel('Number of Records')
plt.title('Patient\'s Race Analysis with Gender')
# Out:
# Text(0.5, 1.0, "Patient's Race Analysis with Gender")

# %% [markdown]
# Most of the patients were Caucasian with almost equivalent ratio of Males and Females within each race.

# %%
#plot the 'age' and 'gender' variables
sns.set()
plt.figure(figsize = (8,5))
ax = sns.countplot(x="age", hue='gender', data=diabetes)
plt.xlabel('Patient\'s Age')
plt.ylabel('Number of Records')
plt.title('Patient\'s Age Analysis with Gender')
# Out:
# Text(0.5, 1.0, "Patient's Age Analysis with Gender")

# %% [markdown]
# There is an almost equivalent ratio of Males and Females within each age group, except in the oldest three age groups. The data seems align with the fact that diabetes and hyperglycaemia are mostly present in higher age groups, above 40.

# %% [markdown]
# ## The target variable: `readmitted`
# **Reminder:
# Both ‘>30 days’ and ‘NO’ readmission categories are grouped together and coded as Class 0 and ‘<30 days’ is coded as Class 1**
#
# Based on the function below defined in the Data Wrangling step, 88.65% of the population were not readmitted <30 days to the hospital after being discharged and around 11.36% of the population were readmitted <30 days. This represents an imbalanced classification problem.

# %%
#re-plotting the graph of the numer of readmissions into the hospital.
#Set xticks labels to display 'No' and '<30' instead if 0 and 1
sns.set()
sns.countplot(data=diabetes, x='readmitted')
plt.xlabel('Readmission to Hospital')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of Records')
# Out:
# Text(0, 0.5, 'Number of Records')

# %%
def calc_prev(x):
    return(sum(x/len(x))*100)

calc_prev(diabetes['readmitted']==0), calc_prev(diabetes['readmitted']==1)
# Out:
# (88.65276583850765, 11.347234161654885)

# %% [markdown]
# **Let's see if certain features (Number of lab procedures, Number of non-lab procedures, Number of medications, Number of Diagnoses) are relevant to hospital readmission**

# %%
#plot the 'readmitted' and the 'num_lab_procedures' variables
#Set xticks labels to display 'No' and '<30' instead if 0 and 1
ax = sns.boxplot(x='readmitted', y='num_lab_procedures', data=diabetes)
plt.xlabel('Readmission into the Hospital')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of lab procedures')
# Out:
# Text(0, 0.5, 'Number of lab procedures')

# %%
#plot the 'readmitted' and the 'num_procedures' variables
#Set xticks labels to display 'No' and '<30' instead if 0 and 1
ax = sns.boxplot(x='readmitted', y='num_procedures', data=diabetes)
plt.xlabel('Readmission into the Hospital')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of lab procedures')
# Out:
# Text(0, 0.5, 'Number of lab procedures')

# %%
#plot the 'readmitted' and the 'num_medications' variables
#Set xticks labels to display 'No' and '<30' instead if 0 and 1
ax = sns.boxplot(x='readmitted', y='num_medications', data=diabetes)
plt.xlabel('Readmission into the Hospital')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of medications')
# Out:
# Text(0, 0.5, 'Number of medications')

# %%
#plot the 'readmitted' and the 'number_diagnoses' variables
#Set xticks labels to display 'No' and '<30' instead if 0 and 1
ax = sns.boxplot(x='readmitted', y='number_diagnoses', data=diabetes)
plt.xlabel('Readmission into the Hospital')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of Diagnoses')
# Out:
# Text(0, 0.5, 'Number of Diagnoses')

# %% [markdown]
# Based on the boxplots above, these features, (Number of lab procedures, Number of non-lab procedures, Number of medications, Number of Diagnoses), seems to have no affect as there is no difference in readmission into a hospital.

# %% [markdown]
# **Let's analyse our main dependent variable, `readmitted`, based on Gender, Race, Age, Admission and Discharge details, A1C result and Glucose serum level.**

# %%
#plot the 'readmitted' and the 'gender' variables
pd.crosstab(diabetes['readmitted'], diabetes['gender']).plot(kind='bar', figsize=(8,5), rot=45)
plt.xlabel('Readmitted')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Gender')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Gender')

# %% [markdown]
# This plot shows that the number of females and males are almost equal between both classes.

# %%
#plot the 'readmitted' and the 'race' variables
plt.figure(figsize = (8,5))
pd.crosstab(diabetes['readmitted'], diabetes['race']).plot(kind='bar', figsize=(8,5), rot=45)
plt.xlabel('Readmitted')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Race')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Race')

# %% [markdown]
# The data appears to show that a higher percentage of Caucasians were readmitted to the hospital, but this most likely a reflection of the individual distributions both 'race' and 'readmitted', shown in earlier graphs.

# %%
#plot the 'readmitted' and the 'age' variables
pd.crosstab(diabetes['readmitted'], diabetes['age']).plot(kind='bar', figsize=(8,5), rot=45)
plt.xlabel('Readmitted')
plt.xticks([0, 1], ['No', '<30'])
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Age')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Age')

# %% [markdown]
# It is not certain whether there is any correlation between patients being readmitted based on age. The distribution of age across both classes is basically the same as the  original distribution of age.

# %%
#plot the 'readmitted' and the 'admission_source_id' variables
#‘>30’ and ‘NO’ readmission categories are grouped as Class 0 and ‘<30’ as Class 1
pd.crosstab(diabetes['admission_source_id'], diabetes['readmitted']).plot(kind='bar', figsize=(8,5))
plt.xlabel('Admission Source')
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Admission Source ID')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Admission Source ID')

# %% [markdown]
# The number of patients being readmitted is highest for the 'Emergency Room', followed by 'Physician referral'.

# %%
#plot the 'readmitted' and the 'admission_type_id' variables
#‘>30’ and ‘NO’ readmission categories are grouped as Class 0 and ‘<30’ as Class 1
pd.crosstab(diabetes['admission_type_id'], diabetes['readmitted']).plot(kind='bar', figsize=(8,5))
plt.xlabel('Admission Type')
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Admission Type ID')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Admission Type ID')

# %% [markdown]
# The number of patients being readmitted is highest for 'Emergency' followed by 'Urgent' and then 'Elective'.

# %%
#plot the 'readmitted' and the 'discharge_disposition_id' variables
#‘>30’ and ‘NO’ readmission categories are grouped as Class 0 and ‘<30’ as Class 1
pd.crosstab(diabetes['discharge_disposition_id'], diabetes['readmitted']).plot(kind='bar',figsize = (8,5))
plt.xlabel('Discharge Disposition')
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Discharge Disposition ID')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Discharge Disposition ID')

# %% [markdown]
# The number of patients being readmitted is highest for 'Discharge to home', followed equally by 'Discharged/transferred to SNF' and 'Discharged/transferred to home with home health service'.

# %%
#plot the 'readmitted' and the 'A1Cresult' variables
#‘>30’ and ‘NO’ readmission categories are grouped as Class 0 and ‘<30’ as Class 1
sns.set()
plt.figure(figsize = (8,5))
sns.countplot(x='A1Cresult', hue='readmitted', data=diabetes)
plt.xlabel('A1C')
plt.ylabel('Number of Records')
plt.title('Patient Readmission with A1C test result')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with A1C test result')

# %% [markdown]
# A1C levels are a strong indicator of Glucose in the body. The majority of the records in our dataset are marked as ‘None’. This is not ideal since A1C is a strong predictor of diabetes in patients. Hopefully, we'll be able to reconcile these records for our analysis.

# %%
#plot the 'readmitted' and the 'max_glu_serum' variables
#‘>30’ and ‘NO’ readmission categories are grouped as Class 0 and ‘<30’ as Class 1
sns.set()
plt.figure(figsize = (8,5))
sns.countplot(x='max_glu_serum', hue='readmitted', data=diabetes)
plt.xlabel('Glucose')
plt.ylabel('Number of Records')
plt.title('Patient Readmission with Glucose test result')
# Out:
# Text(0.5, 1.0, 'Patient Readmission with Glucose test result')

# %% [markdown]
# Similar to A1Cresult, the majority of the records in our dataset are marked as ‘None’.

# %%
#...
